# %%
import cv2

img = cv2.imread("dataset/Ghbli_c1/gt/69945.jpg")
height, width, channels = img.shape
print(f"Kích thước: {width}x{height}, Số kênh màu: {channels}")
# Out:
# Kích thước: 512x512, Số kênh màu: 3
